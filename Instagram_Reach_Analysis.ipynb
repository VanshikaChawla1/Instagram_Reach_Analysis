# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#loading the dataset
os.chdir('/content/drive/MyDrive/')
data=pd.read_csv('Instagram data.csv', encoding='latin-1')
Data=pd.DataFrame(data)
Data.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
Data.tail()
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 114         2      38    373              73       80
# 115         4       1    148              20       18
# 116         0       1     92              34       10
# 117         2      75    549             148      214
# 118         5      26    443             611      228
#
#                                                Caption  \
# 114  Here are some of the best data science certifi...
# 115  Clustering is a machine learning technique use...
# ...

# %%
data.shape
# Out:
# (119, 13)

# %%
Data.shape
# Out:
# (119, 13)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %%
#checking Null values
Data.isnull().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %% [markdown]
# **Performance Analysis**

# %%
Total_impressions=Data['Impressions'].sum()
Total_saves=Data['Saves'].sum()
Total_likes=Data['Likes'].sum()
Total_comments=Data['Comments'].sum()
Total_shares=Data['Shares'].sum()

Engagement_Rate=(Total_likes+Total_comments+Total_shares)/Total_impressions
print('Engagement Rate is calculated as:',Engagement_Rate)
# Out:
# Engagement Rate is calculated as: 0.033276122426429966

# %%
print('Total Impressions:',Total_impressions)
print('Total Saves:',Total_saves)
print('Total Likes:',Total_likes)
print('Total Comments:',Total_comments)
print('Total Shares:',Total_shares)
print('Engagement Rate:',round(Engagement_Rate*100,2),'%')
# Out:
# Total Impressions: 678775
# Total Saves: 18244
# Total Likes: 20680
# Total Comments: 793
# Total Shares: 1114
# Engagement Rate: 3.33 %

# %% [markdown]
# **Source Analysis**

# %%
plt.figure(figsize=(10,8))
plt.style.use('fivethirtyeight')
plt.title("Distribution of Impressions From Home")
sns.distplot(data['From Home'])
plt.show()
# Out:
# <ipython-input-21-3d07cc7c6906>:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
plt.figure(figsize=(10,8))
plt.style.use('fivethirtyeight')
plt.title("Distribution of Impressions From Hashtags")
sns.distplot(data['From Hashtags'])
plt.show()
# Out:
# <ipython-input-22-167928d260c6>:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
plt.figure(figsize=(10,8))
plt.style.use('fivethirtyeight')
plt.title("Distribution of Impressions From Explore")
sns.distplot(data['From Explore'])
plt.show()
# Out:
# <ipython-input-24-e89c2459d75d>:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
plt.figure(figsize=(10,8))
plt.style.use('fivethirtyeight')
plt.title("Distribution of Impressions From Other")
sns.distplot(data['From Other'])
plt.show()
# Out:
# <ipython-input-27-eeb05660332f>:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
Home=Data['From Home'].sum()
Hashtags=Data['From Hashtags'].sum()
Explore=Data['From Explore'].sum()
Other=Data['From Other'].sum()

labels=['Home','Hashtags','Explore','Other']
values=[Home,Hashtags,Explore,Other]

fig=px.pie(data,values=values,names=labels,title='Impressions on Instagram Posts from Various Sources',hole=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **User Behaviour Analysis**

# %%
Total_profile_visits=Data['Profile Visits'].sum()
Total_follows=Data['Follows'].sum()
Total_likes=Data['Likes'].sum()

#Print the total counts
print('Total Profile Visits:',Total_profile_visits)
print('Total Follows:',Total_follows)
print('Total Likes:',Total_likes)

#Create a bar chart for User Behaviour Analysis
plt.figure(figsize=(8,6))
plt.bar(['Profile Visits','Follows','Likes'],[Total_profile_visits,Total_follows,Total_likes])
plt.title('User Behaviour Analysis')
plt.ylabel('Count')
plt.show()
# Out:
# Total Profile Visits: 6024
# Total Follows: 2470
# Total Likes: 20680

# %% [markdown]
# **Analyzing Content**

# %%
pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
words=" ".join(i for i in Data.Caption)
stopwords=set(STOPWORDS)
wc=WordCloud(stopwords=stopwords,background_color="white").generate(words)
plt.figure(figsize=(12,10))
plt.axis("off")
plt.imshow(wc)

# %%
words=" ".join(i for i in Data.Hashtags)
stopwords=set(STOPWORDS)
wc=WordCloud(stopwords=stopwords,background_color="white").generate(words)
plt.figure(figsize=(12,10))
plt.axis("off")
plt.imshow(wc)

# %% [markdown]
# **Analyzing Relationships**

# %%
sns.set(style="darkgrid")
sns.regplot(x=Data['Impressions'],y=Data['Likes']).set(title='Impressions vs Likes')
# Out:
# [Text(0.5, 1.0, 'Impressions vs Likes')]

# %%
sns.set(style="darkgrid")
sns.regplot(x=Data['Impressions'],y=Data['Comments']).set(title='Impressions vs Comments')
# Out:
# [Text(0.5, 1.0, 'Impressions vs Comments')]

# %%
sns.set(style="darkgrid")
sns.regplot(x=Data['Impressions'],y=Data['Shares']).set(title='Impressions vs Shares')
# Out:
# [Text(0.5, 1.0, 'Impressions vs Shares')]

# %%
sns.set(style="darkgrid")
sns.regplot(x=Data['Impressions'],y=Data['Saves']).set(title='Impressions vs Saves')
# Out:
# [Text(0.5, 1.0, 'Impressions vs Saves')]

# %%
numeric=Data.select_dtypes(exclude='object')
correlation=numeric.corr()
print(correlation['Impressions'].sort_values(ascending=False))
# Out:
# Impressions       1.000000
# From Explore      0.893607
# Follows           0.889363
# Likes             0.849835
# From Home         0.844698
# Saves             0.779231
# Profile Visits    0.760981
# Shares            0.634675
# From Other        0.592960
# From Hashtags     0.560760
# Comments         -0.028524
# Name: Impressions, dtype: float64

# %% [markdown]
# **Analyzing Conversion Rate**

# %%
Conversion_Rate=(Data['Follows'].sum()/Data['Profile Visits'].sum())*100
print(Conversion_Rate)
# Out:
# 41.00265604249668

# %%
sns.set(style="darkgrid")
sns.regplot(x=Data['Profile Visits'],y=Data['Follows']).set(title='Profile Visits vs Follows')
# Out:
# [Text(0.5, 1.0, 'Profile Visits vs Follows')]

# %% [markdown]
# **Creating an Instagram Reach Prediction Model**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PassiveAggressiveRegressor

# %%
x=np.array(Data[['Likes','Comments','Shares','Saves','Profile Visits','Follows']])
y=np.array(Data['Impressions'])
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=PassiveAggressiveRegressor()
model.fit(x,y)
model.score(x_test,y_test)
# Out:
# 0.8959013219676492

# %% [markdown]
# **Predicting Instagram Reach**

# %%
model.predict([[282,4,9,233,165,54]])
# Out:
# array([10367.90032107])
